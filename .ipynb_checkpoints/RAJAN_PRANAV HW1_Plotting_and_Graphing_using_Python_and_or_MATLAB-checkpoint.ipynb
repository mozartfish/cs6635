# %%
# libraries and packages
import numpy as np
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
from random import seed
from random import randint
from random import gauss
from array import array

# %%
# PART 1: Generate your own data and Visualize it

# 1) 

# the data
data = [i for i in range(1, 201)]


# visualization
fig1, ax1 = plt.subplots()
ax1.set_title('Boxplot of the numbers 1 to 200')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f19c0b05460>,
#   <matplotlib.lines.Line2D at 0x7f19c0b05250>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f19c072d280>,
#   <matplotlib.lines.Line2D at 0x7f19c0b05d60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f19c0b05490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f19c0b212b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f19c08c8eb0>],
#  'means': []}

# %%
#2

# data
data = [randint(1, 10000) for i in range(10000)]

# visualization
plt.hist(data, bins = 20)
plt.title("Histogram of the frequency of the numbers in the range of 1-10000 using 20 bins")
plt.show()

# %%
# 3

# gaussian variables chosen
mu = 70
sigma = 12

# data
data = [gauss(mu, sigma) for i in range(1, 101)]
print(f"The data: {data}")

# write data to a binary file
f = open("data", "wb")
byte_data = array('d', data)
f.write(byte_data)
f.close()

# visualization
plt.title("Line Graph of 100 random numbers Gaussian Distributed between 1 and 100")
plt.plot(data)
plt.show()
# Out:
# The data: [71.1691455329504, 46.23799316195084, 60.23563869033444, 57.13279124206508, 71.27706560064415, 49.555440867070566, 75.02542649004941, 83.97443564902053, 75.99552719297064, 88.01073597214648, 73.5358962694773, 75.21168079322167, 96.41205100689086, 63.58579739063295, 72.05116299654757, 76.10652599162545, 70.21695441406156, 59.906204277518256, 70.27638421067725, 65.89686469776741, 67.23317273335299, 49.11734829949446, 64.46668097151071, 66.27771387205081, 73.84794317674208, 76.97017734528505, 72.14141681212433, 69.90337062336944, 80.33930163529853, 48.77693306598117, 87.55584347299141, 76.3183332599384, 73.37499463568898, 84.85096488005486, 57.50561910817389, 61.934378195260095, 72.88065437890134, 80.60405753474006, 71.55757307862557, 44.78856931649186, 62.215900167687764, 66.11404116618644, 64.50537119934916, 84.22729191468866, 83.26260920128189, 63.11316622193139, 73.64283472582704, 72.75938531473165, 74.19259484990488, 88.11439619299497, 65.44880265862749, 71.81606594089926, 58.95221075160184, 75.92494289794749, 66.1415937398834, 79.39324252680575, 60.95968755629739, 82.00039215801674, 73.20629812351264, 90.7643080160126, 55.14177242169704, 55.017164668777674, 77.95747412075482, 59.16538933333541, 61.52497617805804, 70.37325353674582, 58.101081985194405, 89.20106641381336, 71.17628514746343, 52.28434643522371, 59.44065086663431, 63.64793051884179, 87.81009209316599, 62.615760538534005, 76.28765177288875, 55.62714140957683, 65.29802292753541, 72.69745891106284, 62.60827535689468, 71.97122467264428, 86.22653283909659, 80.08883426429782, 66.11844998340084, 93.21263684876739, 69.91067855366101, 69.06575103012428, 76.10838397208498, 88.60757455732488, 75.30699075869224, 69.45982419535129, 85.68960212392801, 82.03179333644934, 56.66747599548375, 75.11276198844054, 63.92588399609943, 68.84365123597588, 60.40195878596513, 79.24901803245632, 69.72572508373341, 60.361010161023714]

# %%
# 4)

# read file and get data
f = open('data', 'rb')
data = array('d')
data.fromstring(f.read())
print(f"The data: {data}")

# find the range of the data
data_min = min(data)
data_max = max(data)

print(f"Data Min Value: {data_min}")
print(f"Data Max Value: {data_max}")

# visualization
plt.title("Histogram of 100 random number frequency Gaussian Distributed between 1 and 100 using 7 bins")
plt.hist(data, 7, range = (1, 101))
plt.show()
# Out:
# The data: array('d', [71.1691455329504, 46.23799316195084, 60.23563869033444, 57.13279124206508, 71.27706560064415, 49.555440867070566, 75.02542649004941, 83.97443564902053, 75.99552719297064, 88.01073597214648, 73.5358962694773, 75.21168079322167, 96.41205100689086, 63.58579739063295, 72.05116299654757, 76.10652599162545, 70.21695441406156, 59.906204277518256, 70.27638421067725, 65.89686469776741, 67.23317273335299, 49.11734829949446, 64.46668097151071, 66.27771387205081, 73.84794317674208, 76.97017734528505, 72.14141681212433, 69.90337062336944, 80.33930163529853, 48.77693306598117, 87.55584347299141, 76.3183332599384, 73.37499463568898, 84.85096488005486, 57.50561910817389, 61.934378195260095, 72.88065437890134, 80.60405753474006, 71.55757307862557, 44.78856931649186, 62.215900167687764, 66.11404116618644, 64.50537119934916, 84.22729191468866, 83.26260920128189, 63.11316622193139, 73.64283472582704, 72.75938531473165, 74.19259484990488, 88.11439619299497, 65.44880265862749, 71.81606594089926, 58.95221075160184, 75.92494289794749, 66.1415937398834, 79.39324252680575, 60.95968755629739, 82.00039215801674, 73.20629812351264, 90.7643080160126, 55.14177242169704, 55.017164668777674, 77.95747412075482, 59.16538933333541, 61.52497617805804, 70.37325353674582, 58.101081985194405, 89.20106641381336, 71.17628514746343, 52.28434643522371, 59.44065086663431, 63.64793051884179, 87.81009209316599, 62.615760538534005, 76.28765177288875, 55.62714140957683, 65.29802292753541, 72.69745891106284, 62.60827535689468, 71.97122467264428, 86.22653283909659, 80.08883426429782, 66.11844998340084, 93.21263684876739, 69.91067855366101, 69.06575103012428, 76.10838397208498, 88.60757455732488, 75.30699075869224, 69.45982419535129, 85.68960212392801, 82.03179333644934, 56.66747599548375, 75.11276198844054, 63.92588399609943, 68.84365123597588, 60.40195878596513, 79.24901803245632, 69.72572508373341, 60.361010161023714])
# Data Min Value: 44.78856931649186
# Data Max Value: 96.41205100689086
